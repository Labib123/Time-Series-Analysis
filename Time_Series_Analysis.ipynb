# 2017-12-07  169.03  170.4400  168.9100  169.32  25656110
# 2017-12-08  170.49  171.0000  168.8200  169.37  23285760
# 2017-12-11  169.20  172.8900  168.7900  172.67  34260890
# 2017-12-12  172.15  172.3900  171.4610  171.70  19088170
# 2017-12-13  172.50  173.5400  172.0000  172.27  23402510
# 2017-12-14  172.40  173.1300  171.6500  172.22  20442740
# 2017-12-15  173.63  174.1700  172.4600  173.97  40122100
# 2017-12-18  174.88  177.2000  174.8600  176.42  29385650
# 2017-12-19  175.03  175.3900  174.0900  174.54  27393660
# 2017-12-20  174.87  175.4200  173.2500  174.35  23451420
# 2017-12-21  174.17  176.0200  174.1000  175.01  20848660
# 2017-12-22  174.68  175.4240  174.5000  175.01  16339690
# 2017-12-26  170.80  171.4700  169.6790  170.57  33113340
# 2017-12-27  170.10  170.7800  169.7100  170.60  21477380
# 2017-12-28  171.00  171.8500  170.4800  171.08  16412270
# 2017-12-29  170.52  170.5900  169.2200  169.23  25938760
#
# [151 rows x 5 columns]

# %%
#Retrieve Data based on Month(6)
#data['2017-06':'2017-07']
#data['2017-06':'2017-07'].Low
#data['2017-06':'2017-07'].High.mean()
#data['Close'].resample('Year')

# %%
# %matplotlib inline
data['Close'].plot()

# %% [markdown]
# **Handling holidays and custom calendars**

# %%
rng = pd.date_range(start='7/1/2017' ,end='7/21/2017',freq='B') #Business frequency 
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='B')

# %%
import pandas as pd
US = CustomBusinessDay(calendar=USFederalHolidayCalendar())

rng = pd.date_range(start="7/1/2017", end="7/30/2017", freq=US)

rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-14', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21', '2017-07-24', '2017-07-25',
#                '2017-07-26', '2017-07-27', '2017-07-28'],
#               dtype='datetime64[ns]', freq='C')

# %%
rng = pd.date_range(start="2017-05-25", end="2018-05-27", freq=US)
data.set_index(rng,inplace=True)
data.head()
# Out:
#               Open    High     Low   Close    Volume
# 2017-05-25  154.00  154.24  153.31  153.61  21895020
# 2017-05-26  153.42  154.43  153.33  153.67  20118620
# 2017-05-30  153.97  154.17  152.38  152.76  24452750
# 2017-05-31  153.17  153.33  152.22  153.18  16383610
# 2017-06-01  153.58  155.45  152.89  155.45  27715140

# %% [markdown]
# Retrieving data based on custome freq

# %%
Arabic_weekmask = 'Sun Mon Tue Wen Thu' 
arab_week = CustomBusinessDay(calendar=Arabic_weekmask)

# %%
rng = pd.date_range(start="2017-05-25", end="2018-05-27", freq=arab_week)
rng
# Out:
# DatetimeIndex(['2017-05-25', '2017-05-26', '2017-05-29', '2017-05-30',
#                '2017-05-31', '2017-06-01', '2017-06-02', '2017-06-05',
#                '2017-06-06', '2017-06-07',
#                ...
#                '2018-05-14', '2018-05-15', '2018-05-16', '2018-05-17',
#                '2018-05-18', '2018-05-21', '2018-05-22', '2018-05-23',
#                '2018-05-24', '2018-05-25'],
#               dtype='datetime64[ns]', length=262, freq='C')
